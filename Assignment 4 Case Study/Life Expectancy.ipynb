# %% [markdown]
# # BAMS 3043 Mathematical and Statistical Software
# ## Assignment 4

# %% [markdown]
# **Student Name (With Student ID)**
# - Lim Wei Yang (20WMR09185)
# - Tain Aik Siang (20WMR09189)
# - Yong Yit Ming (20WMR09195)
#
# **Programme of Study (With Group)**
# - RMM3S1 Group 2

# %% [markdown]
# ## Read Data File
# - Remember **pandas** is data management package.

# %%
file = "Life Expectancy.csv"

# %%
import pandas as pd

df = pd.read_csv(file)
df.head(5)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# ## Dependent Variable
# - Life Expectancy: Life expectancy in age
#
# ## Independent Variables
# - Status: Developed / Developing Country
# - Adult Mortality: Adult Mortality Rates of both sexes (probability of dying between 15 and 60 years per 1000
# population)
# - infant deaths: Number of Infant Deaths per 1000 population
# - Alcohol: Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)
# - Percentage expenditure: Expenditure on health as a percentage of Gross Domestic Product per capita (%)
# - Hepatitis B: Hepatitis B immunization coverage among 1-year-olds (%)
# - Measles: Measles - number of reported cases per 1000 population
# - BMI: Average Body Mass Index of entire population
# - under-five deaths: Number of under-five deaths per 1000 population
# - Polio: Polio (Pol3) immunization coverage among 1-year-olds (%)
# - Total expenditure: General government expenditure on health as a percentage of total government expenditure
# (%)
# - Diphtheria: Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)
# - HIV/AIDS: Deaths per 1 000 live births HIV/AIDS (0-4 years)
# - GDP: Gross Domestic Product per capita (in USD)
# - Population: Population of the country
# - thinness 1-19 years: Prevalence of thinness among children and adolescents for Age 10 to 19 (%)
# - thinness 5-9 years: Prevalence of thinness among children for Age 5 to 9(%)
# - Income composition of resources: Human Development Index in terms of income composition of resources (index
# ranging from 0 to 1)
# - Schooling: Number of years of Schooling(years)

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %% [markdown]
# ## The data set have null value
# - We use dropna function to remove null value during Linear Regression Modelling.

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %% [markdown]
# ## Data Visualization
# - Remember `seaborn` is Data Visualization package
# - Remember `matplotlib.pyplot` is Data Visualization package
# - In `sns.set_style` have 5 types style : "darkgrid, whitegrid, dark, white, ticks"

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %%
y = df['Life expectancy ']
fields = list(df.drop('Life expectancy ', axis=1).columns)  # everything except "Life expectancy"
correlations = df[fields].corrwith(y, method = "pearson")
correlations.sort_values(inplace=True)
correlations
# Out:
# Adult Mortality                   -0.696359
#  HIV/AIDS                         -0.556556
#  thinness  1-19 years             -0.477183
#  thinness 5-9 years               -0.471584
# under-five deaths                 -0.222529
# infant deaths                     -0.196557
# Measles                           -0.157586
# Population                        -0.021538
# Year                               0.170033
# Total expenditure                  0.218086
# Hepatitis B                        0.256762
# percentage expenditure             0.381864
# Alcohol                            0.404877
# GDP                                0.461455
# Polio                              0.465556
# Diphtheria                         0.479495
#  BMI                               0.567694
# Income composition of resources    0.724776
# Schooling                          0.751975
# dtype: float64

# %%
sns.set(rc = {'figure.figsize' : (20, 15)})
ax = correlations.plot(kind='bar')
ax.set(ylim=[-1, 1], ylabel='pearson correlation');

# %%
sns.pairplot(df,y_vars=["Life expectancy "], height=4)

# %%
sns.heatmap(df.corr("pearson"), cmap = 'PuOr', fmt = '.2f', annot = True, vmin = -1, vmax = 1, center = 0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Task 1 ( Simple Linear Regression - Model 1 )
# - We pick Schooling Features as the single independent variable for Life Expectancy due to highest correlation between Schooling and Life Expectancy
# - From the Correlation and Pairplot shown above, Correlation between Schooling and Life Expectancy = 0.75
# - OLS can remove missing value by parameter `missing = "drop"`.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

import numpy as np

# %%
X = df['Schooling']
y = df['Life expectancy ']

# %%
X = sm.add_constant(X)
model1 = sm.OLS(y, X, missing = "drop").fit()
#model1 = sm.OLS(y, X)

print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Life expectancy    R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.565
# Method:                 Least Squares   F-statistic:                     3599.
# Date:                Sun, 12 Sep 2021   Prob (F-statistic):               0.00
# Time:                        13:43:31   Log-Likelihood:                -8964.3
# No. Observations:                2768   AIC:                         1.793e+04
# Df Residuals:                    2766   BIC:                         1.794e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         44.1089      0.437    100.992      0.000      43.252      44.965
# ...

# %% [markdown]
# ### The regression model1, Y = 44.1089 + 2.1035X
# - Where Y = Life Expentancy
# - Where X = Schooling
# - R^2 = 0.565
# - p-value = 0.0000 ( p < 0.05 )

# %% [markdown]
# ## Task 2 (MultiLinear Regression - Model 2)
# - We pick Schooling Features and Income composition of resources as the independent variables for Life Expectancy.
# - From the Correlation and Pairplot shown above, Correlation between Schooling and Life Expectancy = 0.75
# - From the Correlation and Pairplot shown above, Correlation between Income composition of resources and Life Expectancy = 0.72
# - OLS can remove missing value by parameter `missing = "drop"`.

# %%
X = df[['Schooling', "Income composition of resources"]]
y = df['Life expectancy ']

# %%
X = sm.add_constant(X)
model2 = sm.OLS(y, X, missing = "drop").fit()
#model1 = sm.OLS(y, X)

print(model2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Life expectancy    R-squared:                       0.608
# Model:                            OLS   Adj. R-squared:                  0.607
# Method:                 Least Squares   F-statistic:                     2141.
# Date:                Sun, 12 Sep 2021   Prob (F-statistic):               0.00
# Time:                        13:43:31   Log-Likelihood:                -8823.1
# No. Observations:                2768   AIC:                         1.765e+04
# Df Residuals:                    2765   BIC:                         1.767e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### The regression model2, Y = 43.7724 + 1.3377X1 + 15.1822X2
# - Where Y = Life Expentancy
# - Where X1 = Schooling
# - Where X2 = Income composition of resources
# - R^2 = 0.608
# - p-value = 0.0000 ( p < 0.05 )

# %% [markdown]
# ## Task 2 (MultiLinear Regression - Model 3)
# - We pick Schooling Features and Adult Mortality as the independent variables for Life Expectancy.
# - From the Correlation and Pairplot shown above, Correlation between Schooling and Life Expectancy = 0.75
# - From the Correlation and Pairplot shown above, Correlation between Adult Mortality and Life Expectancy = -0.7
# - OLS can remove missing value by parameter `missing = "drop"`.

# %%
X = df[['Schooling', "Adult Mortality"]]
y = df['Life expectancy ']

# %%
X = sm.add_constant(X)
model3 = sm.OLS(y, X, missing = "drop").fit()

print(model3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Life expectancy    R-squared:                       0.714
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     3443.
# Date:                Sun, 12 Sep 2021   Prob (F-statistic):               0.00
# Time:                        13:43:31   Log-Likelihood:                -8387.7
# No. Observations:                2768   AIC:                         1.678e+04
# Df Residuals:                    2765   BIC:                         1.680e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              56.0636      0.475    117.981      0.000      55.132      56.995
# ...

# %% [markdown]
# ### The regression model3, Y = 56.0636 + 1.5541X1 - 0.0329X2
# - Where Y = Life Expentancy
# - Where X1 = Schooling
# - Where X2 = Adult Mortality
# - R^2 = 0.714
# - p-value = 0.0000 ( p < 0.05 )

# %% [markdown]
# ## Task 3 Model Comparison
# - We pick **model3** as the best model as **it has the highest R-squared value**
# - There're a few statistical methods to find the best regression model such as
#     - p-values for the predictors
#     - Adjusted R-squared

# %% [markdown]
# - **P-values for the predictors**: In regression, low p-values indicate terms that are statistically significant. “Reducing the model” refers to the practice of including all candidate predictors in the model, and then systematically removing the term with the highest p-value one-by-one until you are left with only significant predictors.
# - However, all the p-values for the selected predictors are all the same, which is 0.0000. Hence, we can't determine the best model yet using this method.

# %% [markdown]
# - **Adjusted R-squared**: Generally, you choose the models that have higher adjusted R-squared values. These statistics are designed to avoid a key problem with regular R-squared—it increases every time you add a predictor and can trick you into specifying an overly complex model.
# - The adjusted R squared increases only if the new term improves the model more than would be expected by chance and it can also decrease with poor quality predictors.

# %% [markdown]
# **Analysis and Evidence:**
#
# R-squared is a goodness-of-fit measure for linear regression models. This statistic indicates the percentage of the variance in the dependent variable that the independent variables explain collectively. R-squared measures the strength of the relationship between your model and the dependent variable on a convenient 0 – 100% scale.
#
# R-squared and the Goodness-of-Fit
#
# R-squared evaluates the scatter of the data points around the fitted regression line. It is also called the coefficient of determination, or the coefficient of multiple determination for multiple regression. For the same data set, higher R-squared values represent smaller differences between the observed data and the fitted values.
#
# R-squared is the percentage of the dependent variable variation that a linear model explains.
#
# R-squared is always between 0 and 100%:
#
# - 0% represents a model that does not explain any of the variation in the response variable around its mean. The mean of the dependent variable predicts the dependent variable as well as the regression model.
# - 100% represents a model that explains all the variation in the response variable around its mean.
#
# Usually, the larger the R-squared, the better the regression model fits your observations.

# %% [markdown]
# ## Task 4 Perform a prediction using the model3 to find the 95% confidence interval of life expectancy
# - We pick model3 as the best model as **it has the highest R-squared value**
# - For the X predictor, We get **Mean Value** for "Schooling and Adult Mortality" from the dataset which are placed between the Minimum value and Maximum Value.

# %%
x1 = round(df['Schooling'].mean(),0)
x2 = round(df['Adult Mortality'].mean(),0)

x1,x2
# Out:
# (12.0, 165.0)

# %% [markdown]
# ## The Predictor
# - X1 = 12
# - X2 = 165

# %% [markdown]
# ## In Manual Calculation (By CASIO fx-570MS)
# *Estimated Y = f(12,165) = 56.0636 + 1.5541 (12) - 0.0329 (165) = 69.2843*
#
# ## From the One Code

# %%
predictions = model3.get_prediction([1,x1,x2])
predictions.summary_frame(alpha=0.05)
# Out:
#         mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  69.285714  0.095279       69.09889      69.472539     59.456342
#
#    obs_ci_upper
# 0     79.115087

# %% [markdown]
# ## From the result above
# - The Estimated Y = **69.285714**
# - Confidence Interval for Y Predict when X1 = 12 and X2 = 165 = [**69.09889,69.472539**]
# - (**Extra**) Prediction Interval for Y Predict when X1 = 12 and X2 = 165 = [**59.456342,79.115087**]
